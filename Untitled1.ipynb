# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans

# %%
img=cv2.imread('resim.webp')
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img=img.reshape((img.shape[1]*img.shape[0],3))

# %%
kmeans=KMeans(n_clusters=5)
s=kmeans.fit(img)

# %%
labels=kmeans.labels_
print(labels)
labels=list(labels)
# Out:
# [0 0 0 ... 0 0 0]

# %%
centroid=kmeans.cluster_centers_
print(centroid)
# Out:
# [[  8.03201225   5.93474644  13.42579322]
#  [  2.70373445   2.35058179 156.04713924]
#  [  4.62277612 101.22734633   6.52661566]
#  [158.29874887   2.5989347    4.74606725]
#  [  9.21856899 189.54128742  11.02718423]]

# %%
percent=[]
for i in range(len(centroid)):
  j=labels.count(i)
  j=j/(len(labels))
  percent.append(j)
print(percent)
# Out:
# [0.428503496201191, 0.20178268434760993, 0.13352975823795782, 0.12503647505106508, 0.11114758616217618]

# %%
plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
plt.show()

# %%
md=[]
for i in range(1,21):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(img)
  o=kmeans.inertia_
  md.append(o)
print(md)
# Out:
# [8372232768.901867, 5467695719.234106, 2986463286.003299, 1336187455.0873036, 1056035651.9433403, 848879944.9976209, 684195552.2422757, 534509218.9789201, 435706939.95903206, 364329844.0165559, 322180073.4689983, 280653143.1458777, 250997246.14652333, 229724870.33232385, 202981405.53582615, 184805550.83719036, 171138267.2477333, 160571741.25220805, 150597748.67311323, 141300458.5768189]

# %%
plt.plot(list(np.arange(1,21)),md)
plt.show()

# %%
kmeans=KMeans(n_clusters=4)
s=kmeans.fit(img)
labels=kmeans.labels_
centroid=kmeans.cluster_centers_
labels=list(labels)
percent=[]
for i in range(len(centroid)):
  j=labels.count(i)
  j=j/(len(labels))
  percent.append(j)
plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
plt.show()
